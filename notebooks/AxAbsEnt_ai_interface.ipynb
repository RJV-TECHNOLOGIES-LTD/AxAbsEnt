# %% [markdown]
# # 🧠 Super_SQL AI System Interface
# This notebook allows real-time control and simulation of the Transcendent AI Agent managing the super_sql architecture.

# %%
import sys
sys.path.append('./ai_system')

from core_agent import SuperSQLAI
ai = SuperSQLAI()

# %% [markdown]
# ### 🔍 Perceive All Registered Domains

# %%
active = ai.perceive(base_path="../architecture")
print("Discovered Domains:", active)

# %% [markdown]
# ### ⚙️ Invoke a Method from a Domain

# %%
# Example domain: quantum_cognition, method: recall_from_entangled_memory
# Modify as needed to invoke any registered module method

result = ai.invoke(domain="quantum_cognition", method="recall_from_entangled_memory")
print("Invocation Result:\n", result)

# %% [markdown]
# ### 🧠 View Current AI Cognitive State

# %%
import yaml
with open("./ai_system/simulation_mind.yaml") as f:
    state = yaml.safe_load(f)
state
