# %% [markdown]
# # 🧭 Unified Initialization of Absolute Entities in Transfinite Isolation
# This notebook inaugurates the absolute lowest-level instantiation possible in computable reality: the irreducible **Absolute Entity** as formalized in the **Enhanced Mathematical Ontology of Absolute Nothingness**.
#
# An Absolute is not a particle, not a field, not a tensor, not even a set—it is the **pre-condition** of all those. It holds an internal **irreducible symmetry core** and a **signature matrix** that remains invariant under all transformations unless interaction is mediated through an entangled state with a foreign absolute via a mediator space.

# %%
from src.axabsent.core.absolute import AbsoluteEntity
import numpy as np

# Construct an absolute entity with no initial relational state
abs_Ω = AbsoluteEntity(
    signature=np.identity(3),  # 3D irreducible core
    state=np.array([1.0, 0.0, 0.0])  # Example directional internal state vector (non-relational)
)

print("Absolute Entity Initialized:")
print(abs_Ω)

# %% [markdown]
# ## 🧬 State Isolation, Identity Invariance & Ontological Enforcement
# The Absolute’s identity **cannot be transformed** arbitrarily. Any attempt to inject relational transformation without mediation should throw a violation of invariance. We test this by attempting to improperly transform the state.

# %%
try:
    abs_Ω.project_state(projection_matrix=np.array([[1.0, 1.0], [0.0, 1.0]]))
except Exception as e:
    print("✅ Invariance Violation Detected:", str(e))

# %% [markdown]
# ## 🔐 Entropy Encoding: Pre-Interaction Readiness Layer
# This operation computes the scalar contraction of the Absolute’s internal signature and encodes a **minimal entropy value** that will later participate in interaction selection minimization during cross-absolute interaction simulation.

# %%
entropy_core_scalar = abs_Ω.encode_selection()
print("Encoded Entropy Scalar:", entropy_core_scalar)

# %% [markdown]
# ## 🌐 High-Dimensional Absolute Identity Embedding
# Let us now instantiate a 7-dimensional Absolute with a symbolic entangled tensor identity. The signature matrix must remain symmetric and square. This extends the Absolute into a formal state that could project across multiple mediator hypersurfaces.

# %%
high_dim_signature = np.random.rand(7, 7)
high_dim_signature = 0.5 * (high_dim_signature + high_dim_signature.T)  # Ensure symmetry

abs_HD = AbsoluteEntity(
    signature=high_dim_signature,
    state=np.random.rand(7)
)

print("High-Dimensional Absolute Signature Matrix (7x7):")
print(abs_HD.signature)
print("Encoded Entropy:", abs_HD.encode_selection())

# %% [markdown]
# ## 🧾 Summary
# You have now:
# - Instantiated the **irreducible Absolute Entity** at transfinite root level.
# - Validated signature symmetry and non-projectability without mediator intervention.
# - Encoded internal entropy for the cross-absolute minimization regime.
# - Extended identity embeddings into **nontrivial high-dimensional topologies**.
#
# 🚀 Continue with `02_absolute_entity_modeling.ipynb` where we will:
# - Categorize absolutes using type theory.
# - Embed absolutes in chain-resonant topologies.
# - Construct ontological containers using category-functor mappings.
