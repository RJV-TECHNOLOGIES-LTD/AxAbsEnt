# %% [markdown]
# # 🧠 Super_SQL AI Trace Visualizer
# Visualize the cognitive trace log and decision events of the AI system.

# %%
import os
log_path = './ai_system/simulation_trace.log'

if os.path.exists(log_path):
    with open(log_path) as f:
        trace = f.read()
    print(trace)
else:
    print("No trace log found.")
